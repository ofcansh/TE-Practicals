# %%
import pandas as pd
import numpy as np
df=pd.read_csv("newdataset.csv")
df
# Out:
#     math_score  reading_score  writing_score  placement_score  \
# 0           62             84             77               81
# 1           75             75             67               75
# 2           64             80             75               86
# 3           67             86             63               90
# 4           80             80             61               75
# 5           67             75             74               92
# 6           75             86             62               90
# 7           60             84             61               88
# 8           71             77             66               93
# 9           60             77             64              100
# 10          67             75             80              100
# 11          75             76             73               90
# 12          63             79             68               92
# 13          76             88             77               82
# ...
