# %%
import tkinter as tk
from tkinter import messagebox

root = tk.Tk()

# Title
root.title("Hello Ansh!")
# Resize
root.geometry('400x500')

# Welcome label
l1 = tk.Label(root, text="Student Registration", fg='black', font=('C059', 14, "bold"))
l1.place(x=100, y=20, width=200, height=30)

# Student Name label
l2 = tk.Label(root, text="Student Name", fg='black')
l2.place(x=30, y=70, width=100)

# Father Name label
l3 = tk.Label(root, text="Father Name", fg='black')
l3.place(x=30, y=110, width=100)

# Gender Label
l4 = tk.Label(root, text="Gender", fg='black')
l4.place(x=30, y=150, width=100)

# Language Known label
l5 = tk.Label(root, text="Language Known", fg='black')
l5.place(x=30, y=190, width=120)

# Email Address label
l6 = tk.Label(root, text="Email Address", fg='black')
l6.place(x=30, y=250, width=100)

# Phone Number label
l7 = tk.Label(root, text="Phone No.", fg='black')
l7.place(x=30, y=290, width=100)

# Entry for Student Name
t1 = tk.Entry(root, width=25)
t1.place(x=150, y=70, width=200, height=25)

# Entry for Father Name
t2 = tk.Entry(root, width=25)
t2.place(x=150, y=110, width=200, height=25)

# Entry for Email Address
t3 = tk.Entry(root, width=25)
t3.place(x=150, y=250, width=200, height=25)

# Entry for Phone Number
t4 = tk.Entry(root, width=25)
t4.place(x=150, y=290, width=200, height=25)

# Radio buttons for Gender
gender = tk.StringVar()
gender.set(None) 

r1 = tk.Radiobutton(root, text="Male", value="Male", variable=gender)
r1.place(x=150, y=150)

r2 = tk.Radiobutton(root, text="Female", value="Female", variable=gender)
r2.place(x=250, y=150)

# Checkbuttons for Languages
lang_english = tk.BooleanVar()
lang_hindi = tk.BooleanVar()
lang_marathi = tk.BooleanVar()

cb1 = tk.Checkbutton(root, text="English", variable=lang_english)
cb1.place(x=150, y=190)

cb2 = tk.Checkbutton(root, text="Hindi", variable=lang_hindi)
cb2.place(x=150, y=220)

cb3 = tk.Checkbutton(root, text="Marathi", variable=lang_marathi)
cb3.place(x=250, y=190)

# Submit button
def submit():
    messagebox.showinfo("Success", "Form Submitted Successfully")
    
b1 = tk.Button(root, text="Submit", command=submit)
b1.place(x=150, y=350, width=100, height=30)

root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk

root = tk.Tk()

# Title
root.title("Hello Ansh!")
# Resize
root.geometry('400x550')

# Welcome label
l1 = tk.Label(root, text="Student Registration", fg='black', font=('C059', 14, "bold"))
l1.place(x=100, y=20, width=200, height=30)

# Student Name label
l2 = tk.Label(root, text="Student Name", fg='black')
l2.place(x=30, y=70, width=100)

# Father Name label
l3 = tk.Label(root, text="Father Name", fg='black')
l3.place(x=30, y=110, width=100)

# Gender Label
l4 = tk.Label(root, text="Gender", fg='black')
l4.place(x=30, y=150, width=100)

# Language Known label
l5 = tk.Label(root, text="Language Known", fg='black')
l5.place(x=30, y=190, width=120)

# Email Address label
l6 = tk.Label(root, text="Email Address", fg='black')
l6.place(x=30, y=250, width=100)

# Phone Number label
l7 = tk.Label(root, text="Phone No.", fg='black')
l7.place(x=30, y=290, width=100)

# Entry for Student Name
t1 = tk.Entry(root, width=25)
t1.place(x=150, y=70, width=200, height=25)

# Entry for Father Name
t2 = tk.Entry(root, width=25)
t2.place(x=150, y=110, width=200, height=25)

# Entry for Email Address
t3 = tk.Entry(root, width=25)
t3.place(x=150, y=250, width=200, height=25)

# Entry for Phone Number
t4 = tk.Entry(root, width=25)
t4.place(x=150, y=290, width=200, height=25)

# Radio buttons for Gender
gender = tk.StringVar()
gender.set(None) 

r1 = tk.Radiobutton(root, text="Male", value="Male", variable=gender)
r1.place(x=150, y=150)

r2 = tk.Radiobutton(root, text="Female", value="Female", variable=gender)
r2.place(x=250, y=150)

# Checkbuttons for Languages
lang_english = tk.BooleanVar()
lang_hindi = tk.BooleanVar()
lang_marathi = tk.BooleanVar()

cb1 = tk.Checkbutton(root, text="English", variable=lang_english)
cb1.place(x=150, y=190)

cb2 = tk.Checkbutton(root, text="Hindi", variable=lang_hindi)
cb2.place(x=150, y=220)

cb3 = tk.Checkbutton(root, text="Marathi", variable=lang_marathi)
cb3.place(x=250, y=190)

# Dropdown for Grade or Course
l8 = tk.Label(root, text="Select Grade/Course", fg='black')
l8.place(x=30, y=320, width=150)

grade_course = ttk.Combobox(root, values=["Grade 1", "Grade 2", "Course A", "Course B"])
grade_course.place(x=200, y=320, width=100)
grade_course.current(0)  # Set default selection

# Submit button
def submit():
    messagebox.showinfo("Success", "Form Submitted Successfully")

b1 = tk.Button(root, text="Submit", command=submit)
b1.place(x=150, y=370, width=100, height=30)

root.mainloop()
